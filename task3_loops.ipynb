# %%
#Task3-Loops for Dataset processing
#  for loop

numbers = [10, 20, 30, 40, 50]

for num in numbers:
    print(num)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
# using range()

for i in range(1, 6):
    print("Iteration:", i)
# Out:
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5

# %%
# while loop

count = 1

while count <= 5:
    print("Count:", count)
    count += 1
# Out:
# Count: 1
# Count: 2
# Count: 3
# Count: 4
# Count: 5

# %%
# Numerical dataset

marks = [78, 85, 62, 90, 74, 88, 69, 95, 81, 73]

print("Student Marks:")
for mark in marks:
    print(mark)
# Out:
# Student Marks:
# 78
# 85
# 62
# 90
# 74
# 88
# 69
# 95
# 81
# 73

# %%
#calculate total and average using loop
total = 0

for mark in marks:
    total += mark

average = total / len(marks)

print("Total Marks:", total)
print("Average Marks:", average)
# Out:
# Total Marks: 795
# Average Marks: 79.5

# %%
#maximum and minimum

maximum = marks[0]
minimum = marks[0]

for mark in marks:
    if mark > maximum:
        maximum = mark
    
    if mark < minimum:
        minimum = mark

print("Maximum Marks:", maximum)
print("Minimum Marks:", minimum)
# Out:
# Maximum Marks: 95
# Minimum Marks: 62

# %%
#count pass and fail student

pass_count = 0
fail_count = 0

for mark in marks:
    if mark >= 40:
        pass_count += 1
    else:
        fail_count += 1

print("Number of Passed Students:", pass_count)
print("Number of Failed Students:", fail_count)
# Out:
# Number of Passed Students: 10
# Number of Failed Students: 0

# %%
#summary statistics using loop
total = 0
count = 0

for mark in marks:
    total += mark
    count += 1

average = total / count

print("Number of Students:", count)
print("Total Marks:", total)
print("Average Marks:", average)
print("Maximum Marks:", max(marks))
print("Minimum Marks:", min(marks))
# Out:
# Number of Students: 10
# Total Marks: 795
# Average Marks: 79.5
# Maximum Marks: 95
# Minimum Marks: 62

# %%
#dictionary loop example
student_marks = {
    "Amit": 78,
    "Priya": 85,
    "Rahul": 62,
    "Sneha": 90,
    "Neha": 74
}

for name, mark in student_marks.items():
    print(name, ":", mark)
# Out:
# Amit : 78
# Priya : 85
# Rahul : 62
# Sneha : 90
# Neha : 74

# %%
#final output
print("Task 3 completed successfully!")
print("For and while loops were used for basic dataset processing.")
print("Total, average, maximum, minimum, and pass/fail counts were calculated.")
# Out:
# Task 3 completed successfully!
# For and while loops were used for basic dataset processing.
# Total, average, maximum, minimum, and pass/fail counts were calculated.
